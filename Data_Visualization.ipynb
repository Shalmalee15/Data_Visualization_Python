# %% [markdown]
# # Starting with, of course, "Hello World!"

# %%
print("Hello, World")
# Out:
# Hello, World

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib

# Load the data file
filename = '/home/shalmalee/Desktop/Data_Visualization_Python/Ex_Files_Python_Data_Visualization/Exercise_Files/3 Pandas/data/car_financing.csv'
df = pd.read_csv(filename)

# %%
df
# Out:
#      Month  Starting Balance  Repayment  Interest Paid  Principal Paid  New Balance  term  interest_rate       car_type
# 0        1          34689.96     687.23         202.93          484.30     34205.66    60         0.0702  Toyota Sienna
# 1        2          34205.66     687.23         200.10          487.13     33718.53    60         0.0702  Toyota Sienna
# 2        3          33718.53     687.23         197.25          489.98     33228.55    60         0.0702  Toyota Sienna
# 3        4          33228.55     687.23         194.38          492.85     32735.70    60         0.0702  Toyota Sienna
# 4        5          32735.70     687.23         191.50          495.73     32239.97    60         0.0702  Toyota Sienna
# ..     ...               ...        ...            ...             ...          ...   ...            ...            ...
# 403     56           3951.11     796.01           9.54          786.47      3164.64    60         0.0290      VW Golf R
# 404     57           3164.64     796.01           7.64          788.37      2376.27    60         0.0290      VW Golf R
# 405     58           2376.27     796.01           5.74          790.27      1586.00    60         0.0290      VW Golf R
# 406     59           1586.00     796.01           3.83          792.18       793.82    60         0.0290      VW Golf R
# 407     60            793.82     796.01           1.91          794.10        -0.28    60         0.0290      VW Golf R
#
# [408 rows x 9 columns]

# %%
filename_1 = '/home/shalmalee/Desktop/Data_Visualization_Python/Ex_Files_Python_Data_Visualization/Exercise_Files/3 Pandas/data/car_financing.xlsx'
df_1 = pd.read_excel(filename_1)

# %%
df_1
# Out:
#      Month  Starting Balance  Repayment  Interest Paid  Principal Paid  New Balance  term  interest_rate       car_type
# 0        1          34689.96     687.23         202.93          484.30     34205.66    60         0.0702  Toyota Sienna
# 1        2          34205.66     687.23         200.10          487.13     33718.53    60         0.0702  Toyota Sienna
# 2        3          33718.53     687.23         197.25          489.98     33228.55    60         0.0702  Toyota Sienna
# 3        4          33228.55     687.23         194.38          492.85     32735.70    60         0.0702  Toyota Sienna
# 4        5          32735.70     687.23         191.50          495.73     32239.97    60         0.0702  Toyota Sienna
# ..     ...               ...        ...            ...             ...          ...   ...            ...            ...
# 403     56           3951.11     796.01           9.54          786.47      3164.64    60         0.0290      VW Golf R
# 404     57           3164.64     796.01           7.64          788.37      2376.27    60         0.0290      VW Golf R
# 405     58           2376.27     796.01           5.74          790.27      1586.00    60         0.0290      VW Golf R
# 406     59           1586.00     796.01           3.83          792.18       793.82    60         0.0290      VW Golf R
# 407     60            793.82     796.01           1.91          794.10        -0.28    60         0.0290      VW Golf R
#
# [408 rows x 9 columns]

# %%
df.head() # Select top N number of records (default=5)
df.tail() # Select bottom N number of columns (default=5)
# Out:
#      Month  Starting Balance  Repayment  Interest Paid  Principal Paid  New Balance  term  interest_rate   car_type
# 403     56           3951.11     796.01           9.54          786.47      3164.64    60          0.029  VW Golf R
# 404     57           3164.64     796.01           7.64          788.37      2376.27    60          0.029  VW Golf R
# 405     58           2376.27     796.01           5.74          790.27      1586.00    60          0.029  VW Golf R
# 406     59           1586.00     796.01           3.83          792.18       793.82    60          0.029  VW Golf R
# 407     60            793.82     796.01           1.91          794.10        -0.28    60          0.029  VW Golf R

# %%
# Check the column data types 
df.dtypes
# Out:
# Month                 int64
# Starting Balance    float64
# Repayment           float64
# Interest Paid       float64
# Principal Paid      float64
# New Balance         float64
# term                  int64
# interest_rate       float64
# car_type             object
# dtype: object

# %%
df.shape
# Out:
# (408, 9)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 408 entries, 0 to 407
# Data columns (total 9 columns):
# Month               408 non-null int64
# Starting Balance    408 non-null float64
# Repayment           408 non-null float64
# Interest Paid       407 non-null float64
# Principal Paid      408 non-null float64
# New Balance         408 non-null float64
# term                408 non-null int64
# interest_rate       408 non-null float64
# car_type            408 non-null object
# dtypes: float64(6), int64(2), object(1)
# memory usage: 28.8+ KB

# %% [markdown]
# # Slicing
# 1. How to select columns in pandas
# 2. How to use slicing operations in pandas

# %%
df.head()
# Out:
#    Month  Starting Balance  Repayment  Interest Paid  Principal Paid  New Balance  term  interest_rate       car_type
# 0      1          34689.96     687.23         202.93          484.30     34205.66    60         0.0702  Toyota Sienna
# 1      2          34205.66     687.23         200.10          487.13     33718.53    60         0.0702  Toyota Sienna
# 2      3          33718.53     687.23         197.25          489.98     33228.55    60         0.0702  Toyota Sienna
# 3      4          33228.55     687.23         194.38          492.85     32735.70    60         0.0702  Toyota Sienna
# 4      5          32735.70     687.23         191.50          495.73     32239.97    60         0.0702  Toyota Sienna

# %%
df[['car_type']].head()
# Out:
#         car_type
# 0  Toyota Sienna
# 1  Toyota Sienna
# 2  Toyota Sienna
# 3  Toyota Sienna
# 4  Toyota Sienna

# %%
df[['car_type', 'Principal Paid']].head()
# Out:
#         car_type  Principal Paid
# 0  Toyota Sienna          484.30
# 1  Toyota Sienna          487.13
# 2  Toyota Sienna          489.98
# 3  Toyota Sienna          492.85
# 4  Toyota Sienna          495.73

# %%
type(df['car_type'])
# Out:
# pandas.core.series.Series

# %%
df['car_type']
# Out:
# 0      Toyota Sienna
# 1      Toyota Sienna
# 2      Toyota Sienna
# 3      Toyota Sienna
# 4      Toyota Sienna
#            ...
# 403        VW Golf R
# 404        VW Golf R
# 405        VW Golf R
# 406        VW Golf R
# 407        VW Golf R
# Name: car_type, Length: 408, dtype: object

# %%
df['car_type'][0:11]
# Out:
# 0     Toyota Sienna
# 1     Toyota Sienna
# 2     Toyota Sienna
# 3     Toyota Sienna
# 4     Toyota Sienna
# 5     Toyota Sienna
# 6     Toyota Sienna
# 7     Toyota Sienna
# 8     Toyota Sienna
# 9     Toyota Sienna
# 10    Toyota Sienna
# Name: car_type, dtype: object

# %%
df.loc[:,['car_type']].head()
# Out:
#         car_type
# 0  Toyota Sienna
# 1  Toyota Sienna
# 2  Toyota Sienna
# 3  Toyota Sienna
# 4  Toyota Sienna

# %%
df.loc[:, 'car_type'].head()
# Out:
# 0    Toyota Sienna
# 1    Toyota Sienna
# 2    Toyota Sienna
# 3    Toyota Sienna
# 4    Toyota Sienna
# Name: car_type, dtype: object

# %% [markdown]
# # Filter the data

# %%
#Value counts method
df['car_type'].value_counts()
# Out:
# VW Golf R         144
# Toyota Sienna     120
# Toyota Carolla    111
# Toyota Corolla     33
# Name: car_type, dtype: int64

# %%
car_filter = df['car_type'] == 'Toyota Sienna'

# %%
car_filter.head()
# Out:
# 0    True
# 1    True
# 2    True
# 3    True
# 4    True
# Name: car_type, dtype: bool

# %%
df[car_filter].head()
# Out:
#    Month  Starting Balance  Repayment  Interest Paid  Principal Paid  New Balance  term  interest_rate       car_type
# 0      1          34689.96     687.23         202.93          484.30     34205.66    60         0.0702  Toyota Sienna
# 1      2          34205.66     687.23         200.10          487.13     33718.53    60         0.0702  Toyota Sienna
# 2      3          33718.53     687.23         197.25          489.98     33228.55    60         0.0702  Toyota Sienna
# 3      4          33228.55     687.23         194.38          492.85     32735.70    60         0.0702  Toyota Sienna
# 4      5          32735.70     687.23         191.50          495.73     32239.97    60         0.0702  Toyota Sienna

# %%
df.loc[car_filter,:]  # : all the columns
# Out:
#      Month  Starting Balance  Repayment  Interest Paid  Principal Paid  New Balance  term  interest_rate       car_type
# 0        1          34689.96     687.23         202.93          484.30     34205.66    60         0.0702  Toyota Sienna
# 1        2          34205.66     687.23         200.10          487.13     33718.53    60         0.0702  Toyota Sienna
# 2        3          33718.53     687.23         197.25          489.98     33228.55    60         0.0702  Toyota Sienna
# 3        4          33228.55     687.23         194.38          492.85     32735.70    60         0.0702  Toyota Sienna
# 4        5          32735.70     687.23         191.50          495.73     32239.97    60         0.0702  Toyota Sienna
# ..     ...               ...        ...            ...             ...          ...   ...            ...            ...
# 115     56           3133.83     632.47           9.37          623.10      2510.73    60         0.0359  Toyota Sienna
# 116     57           2510.73     632.47           7.51          624.96      1885.77    60         0.0359  Toyota Sienna
# 117     58           1885.77     632.47           5.64          626.83      1258.94    60         0.0359  Toyota Sienna
# 118     59           1258.94     632.47           3.76          628.71       630.23    60         0.0359  Toyota Sienna
# 119     60            630.23     632.47           1.88          630.59        -0.36    60         0.0359  Toyota Sienna
#
# [120 rows x 9 columns]

# %%
df['car_type'].value_counts()
# Out:
# VW Golf R         144
# Toyota Sienna     120
# Toyota Carolla    111
# Toyota Corolla     33
# Name: car_type, dtype: int64

# %% [markdown]
# # Interest rate Filter

# %%
df.head()
# Out:
#    Month  Starting Balance  Repayment  Interest Paid  Principal Paid  New Balance  term  interest_rate       car_type
# 0      1          34689.96     687.23         202.93          484.30     34205.66    60         0.0702  Toyota Sienna
# 1      2          34205.66     687.23         200.10          487.13     33718.53    60         0.0702  Toyota Sienna
# 2      3          33718.53     687.23         197.25          489.98     33228.55    60         0.0702  Toyota Sienna
# 3      4          33228.55     687.23         194.38          492.85     32735.70    60         0.0702  Toyota Sienna
# 4      5          32735.70     687.23         191.50          495.73     32239.97    60         0.0702  Toyota Sienna

# %%
df['interest_rate'].value_counts()
# Out:
# 0.0290    144
# 0.0390    144
# 0.0359     60
# 0.0702     60
# Name: interest_rate, dtype: int64

# %%
df['term'].value_counts()
# Out:
# 60    240
# 48     96
# 36     72
# Name: term, dtype: int64

# %%
df['Repayment'].value_counts()
# Out:
# 796.01     60
# 632.47     60
# 396.82     60
# 687.23     60
# 486.74     48
# 981.02     48
# 636.76     36
# 1289.53    36
# Name: Repayment, dtype: int64

# %%
df['interest_rate'] == 0.0702
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#        ...
# 403    False
# 404    False
# 405    False
# 406    False
# 407    False
# Name: interest_rate, Length: 408, dtype: bool

# %%
interest_filter = df['interest_rate']==0.0702

# %%
df = df.loc[interest_filter, :]

# %%
df['interest_rate'].value_counts(dropna=False)
# Out:
# 0.0702    60
# Name: interest_rate, dtype: int64

# %%
df['interest_rate'].value_counts()
# Out:
# 0.0702    60
# Name: interest_rate, dtype: int64

# %%
df.loc[car_filter & interest_filter, :]
# Out:
#     Month  Starting Balance  Repayment  Interest Paid  Principal Paid  New Balance  term  interest_rate       car_type
# 0       1          34689.96     687.23         202.93          484.30     34205.66    60         0.0702  Toyota Sienna
# 1       2          34205.66     687.23         200.10          487.13     33718.53    60         0.0702  Toyota Sienna
# 2       3          33718.53     687.23         197.25          489.98     33228.55    60         0.0702  Toyota Sienna
# 3       4          33228.55     687.23         194.38          492.85     32735.70    60         0.0702  Toyota Sienna
# 4       5          32735.70     687.23         191.50          495.73     32239.97    60         0.0702  Toyota Sienna
# 5       6          32239.97     687.23         188.60          498.63     31741.34    60         0.0702  Toyota Sienna
# 6       7          31741.34     687.23         185.68          501.55     31239.79    60         0.0702  Toyota Sienna
# 7       8          31239.79     687.23         182.75          504.48     30735.31    60         0.0702  Toyota Sienna
# 8       9          30735.31     687.23         179.80          507.43     30227.88    60         0.0702  Toyota Sienna
# 9      10          30227.88     687.23         176.83          510.40     29717.48    60         0.0702  Toyota Sienna
# 10     11          29717.48     687.23         173.84          513.39     29204.09    60         0.0702  Toyota Sienna
# 11     12          29204.09     687.23         170.84          516.39     28687.70    60         0.0702  Toyota Sienna
# 12     13          28687.70     687.23         167.82          519.41     28168.29    60         0.0702  Toyota Sienna
# 13     14          28168.29     687.23         164.78          522.45     27645.84    60         0.0702  Toyota Sienna
# 14     15          27645.84     687.23         161.72          525.51     27120.33    60         0.0702  Toyota Sienna
# 15     16          27120.33     687.23         158.65          528.58     26591.75    60         0.0702  Toyota Sienna
# 16     17          26591.75     687.23         155.56          531.67     26060.08    60         0.0702  Toyota Sienna
# 17     18          26060.08     687.23         152.45          534.78     25525.30    60         0.0702  Toyota Sienna
# 18     19          25525.30     687.23         149.32          537.91     24987.39    60         0.0702  Toyota Sienna
# 19     20          24987.39     687.23         146.17          541.06     24446.33    60         0.0702  Toyota Sienna
# 20     21          24446.33     687.23         143.01          544.22     23902.11    60         0.0702  Toyota Sienna
# 21     22          23902.11     687.23         139.82          547.41     23354.70    60         0.0702  Toyota Sienna
# 22     23          23354.70     687.23         136.62          550.61     22804.09    60         0.0702  Toyota Sienna
# 23     24          22804.09     687.23         133.40          553.83     22250.26    60         0.0702  Toyota Sienna
# 24     25          22250.26     687.23         130.16          557.07     21693.19    60         0.0702  Toyota Sienna
